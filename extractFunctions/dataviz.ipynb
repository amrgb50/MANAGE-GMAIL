# %%
import pandas as pd

# %%
pd.read_csv('/Users/abhaymone/src/dev/sand/MANAGE-GMAIL/data/extract.csv',index_col= 0, usecols=['msg_id','labels','receivedDt','from'])
# Out:
#                                                              labels  \
# msg_id
# 182a4773efc034d8  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 182a3c014030b110            ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']
# 182a3beb923b7e4b            ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']
# 182a1c9030642764           ['UNREAD', 'CATEGORY_PERSONAL', 'INBOX']
# 182a1b3cbcbc83ad  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 182a191b99f0d8ee  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 182a0c4ab6a68613  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 182a075a9954ed81            ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']
# 182a02e2ecf3d7e5  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 182a0180a8e65221            ['UNREAD', 'CATEGORY_UPDATES', 'INBOX']
# 1829fc88fd4a6ccd  ['UNREAD', 'IMPORTANT', 'CATEGORY_UPDATES', 'I...
# 1828f1a406067406  ['UNREAD', 'IMPORTANT', 'CATEGORY_PERSONAL', '...
# 1828f19fb51320cc  ['UNREAD', 'IMPORTANT', 'CATEGORY_PERSONAL', '...
# ...
